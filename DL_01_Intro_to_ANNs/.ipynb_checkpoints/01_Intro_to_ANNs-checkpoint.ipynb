# %% [markdown]
# # Intro to ANNs

# %% [markdown]
# Artificial Neural Networks are inspired in Biological Neural Networks (how the neurons work & are connected in an animal brain)

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# When mapped it can be seen that neurons are organised in consecutive layers.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# ## Logical Computation with Neurons

# %% [markdown]
# A simple model of the biological neuron, which later became known as an artificial neuron: it has one or more binary (on/off) inputs and one binary output. The artificial neuron simply activates its out‐ put when more than a certain number of its inputs are active.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>
