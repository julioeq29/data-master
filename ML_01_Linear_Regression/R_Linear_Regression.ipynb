# %% [markdown]
# # Linear Regression

# %% [markdown]
# **Training a model:**
# - It means setting its parameters so that the model best fits the training set
# - We need a measure of how well (or poorly) the model fits the training set 👉 `Performance Measure`:
#     - We need to minimise the Cost Function
#         - RMSE - Root Mean Square Error

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()

# %% [markdown]
# Comparison of algorithms for Linear Regression
#
# *SVD = Singular Value Decomposition

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>
