# %% [markdown]
# # Learning Curves

# %% [markdown]
# Plots of the model's performance on the training set and the validation set as a function of the training set size (or the training set iteration).
#
# To generate:
# - Train the model several times on different sized subsets of the training set

# %% [markdown]
# ### Underfitting training data

# %% [markdown]
# `Linear Regression`
#
# Both curves reach a plateau; they are close and fairly high.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# ### Overfitting training data

# %% [markdown]
# `Polynomial Features`
#
# - Error on training data is much lower than pure LinReg
# - There is a gap between the curves, this means model performs significantly better on the training that test **not generalises well**.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>
