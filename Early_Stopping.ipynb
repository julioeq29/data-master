# %% [markdown]
# # Early Stopping

# %% [markdown]
# As the epochs go by:
# - the algorithm learns and
# - its prediction error (RMSE) on the training set naturally goes down, and
# - so does its prediction error on the validation set.
#
# After a while, `the validation error stops decreasing and actually starts to go back up`. This indicates that the model has started to overfit the training data. With early stop‐ ping you just stop training as soon as the validation error reaches the minimum.

# %% [markdown]
# 🔥 For **Stochastic_GD and Mini-batch_GD, the curves are not so smooth**.
#
# A possible solution:
# - Stop when validation error has been above minimum for some time and then
# - Roll back the model parameters to the point where validation error was at minimum

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>
